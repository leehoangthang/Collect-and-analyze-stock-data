# %%
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# thu thập dữ liệu của web stockanalysis

# %%
url = "https://stockanalysis.com/stocks/"

driver = webdriver.Chrome(executable_path=r"C:\Users\Hoang Thang\Downloads\chromedriver-win32\chromedriver-win32\chromedriver.exe")

driver.get(url)
time.sleep(2)  # Allow time for the page to load

# Extract data from the first page
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df = pd.read_html(str(tables[0]))[0]


df
# Out:
#     Symbol                     Company Name                        Industry  \
# 0        A             Agilent Technologies          Diagnostics & Research
# 1       AA                            Alcoa                        Aluminum
# 2     AACG            ATA Creativity Global   Education & Training Services
# 3     AACI             Armada Acquisition I                 Shell Companies
# 4     AACT  Ares Acquisition Corporation II                 Shell Companies
# ..     ...                              ...                             ...
# 495   ATRA            Atara Biotherapeutics                   Biotechnology
# 496   ATRC                         AtriCure  Medical Instruments & Supplies
# 497   ATRI                           Atrion  Medical Instruments & Supplies
# 498   ATRO                        Astronics             Aerospace & Defense
# 499    ATS                  ATS Corporation  Specialty Industrial Machinery
#
#     Market Cap
# 0       38.38B
# 1        5.46B
# ...

# %% [markdown]
# lấy bảng tiếp theo phải click

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df1 = pd.read_html(str(tables[0]))[0]
df1
# Out:
#     Symbol                       Company Name                       Industry  \
# 0        A               Agilent Technologies         Diagnostics & Research
# 1       AA                              Alcoa                       Aluminum
# 2     AACG              ATA Creativity Global  Education & Training Services
# 3     AACI               Armada Acquisition I                Shell Companies
# 4     AACT    Ares Acquisition Corporation II                Shell Companies
# ..     ...                                ...                            ...
# 995    CCM  Concord Medical Services Holdings        Medical Care Facilities
# 996   CCNE                      CNB Financial               Banks - Regional
# 997    CCO     Clear Channel Outdoor Holdings           Advertising Agencies
# 998   CCOI     Cogent Communications Holdings               Telecom Services
# 999   CCRD                           CoreCard         Software - Application
#
#     Market Cap
# 0       38.38B
# ...

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df2 = pd.read_html(str(tables[0]))[0]
df2
# Out:
#     Symbol                            Company Name                   Industry  \
# 0     CCRN                Cross Country Healthcare    Medical Care Facilities
# 1      CCS                     Century Communities   Residential Construction
# 2     CCSI               Consensus Cloud Solutions  Software - Infrastructure
# 3     CCTG  CCSC Technology International Holdings          Computer Hardware
# 4     CCTS              Cactus Acquisition Corp. 1            Shell Companies
# ..     ...                                     ...                        ...
# 995   FNLC                       The First Bancorp           Banks - Regional
# 996    FNV                           Franco-Nevada                       Gold
# 997   FNVT                   Finnovate Acquisition            Shell Companies
# 998   FNWB                 First Northwest Bancorp           Banks - Regional
# 999   FNWD                         Finward Bancorp           Banks - Regional
#
#     Market Cap
# 0      769.45M
# ...

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df3 = pd.read_html(str(tables[0]))[0]
df3
# Out:
#     Symbol                  Company Name                          Industry  \
# 0      FOA  Finance Of America Companies                   Credit Services
# 1     FOLD           Amicus Therapeutics                     Biotechnology
# 2     FONR                         FONAR                   Medical Devices
# 3      FOR                Forestar Group         Real Estate - Development
# 4     FORA                        Forian       Health Information Services
# ..     ...                           ...                               ...
# 995   LGMK                     LogicMark    Security & Protection Services
# 996   LGND        Ligand Pharmaceuticals                     Biotechnology
# 997    LGO                         Largo  Other Industrial Metals & Mining
# 998   LGST    Semper Paratus Acquisition                   Shell Companies
# 999   LGVC        LAMF Global Ventures I                   Shell Companies
#
#     Market Cap
# 0       85.46M
# 1        3.62B
# 2      126.95M
# ...

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df4 = pd.read_html(str(tables[0]))[0]
df4
# Out:
#     Symbol                                Company Name  \
# 0     LGVN                                  Longeveron
# 1       LH  Laboratory Corporation of America Holdings
# 2      LHX                       L3Harris Technologies
# 3       LI                                     Li Auto
# 4     LIAN                                     LianBio
# ..     ...                                         ...
# 995   PINS                                   Pinterest
# 996   PIPR                     Piper Sandler Companies
# 997   PIRS                      Pieris Pharmaceuticals
# 998   PIXY                                   ShiftPixy
# 999    PJT                                PJT Partners
#
#                            Industry Market Cap
# 0                     Biotechnology     20.09M
# 1            Diagnostics & Research     19.10B
# 2               Aerospace & Defense     39.65B
# 3                Auto Manufacturers     27.95B
# 4                     Biotechnology    450.11M
# ...

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df5 = pd.read_html(str(tables[0]))[0]
df5
# Out:
#     Symbol                      Company Name  \
# 0       PK             Park Hotels & Resorts
# 1     PKBK                     Parke Bancorp
# 2      PKE                    Park Aerospace
# 3      PKG  Packaging Corporation of America
# 4     PKOH                Park-Ohio Holdings
# ..     ...                               ...
# 995   TIGR                UP Fintech Holding
# 996    TIL                        Instil Bio
# 997   TILE                         Interface
# 998   TIMB                          TIM S.A.
# 999    TIO                       Tingo Group
#
#                                Industry Market Cap
# 0                  REIT - Hotel & Motel      3.27B
# 1                      Banks - Regional    227.58M
# 2                   Aerospace & Defense    317.78M
# 3                Packaging & Containers     15.41B
# 4        Specialty Industrial Machinery    333.75M
# ..                                  ...        ...
# 995                     Capital Markets    584.95M
# ...

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
tables = soup.find_all('table', 'svelte-1jtwn20')
df6 = pd.read_html(str(tables[0]))[0]
df6
# Out:
#     Symbol                Company Name                        Industry  \
# 0     TIPT                     Tiptree           Insurance - Specialty
# 1     TIRX      Tian Ruixiang Holdings               Insurance Brokers
# 2     TISI                  Team, Inc.     Specialty Business Services
# 3     TITN             Titan Machinery         Industrial Distribution
# 4     TIVC        Tivic Health Systems                 Medical Devices
# ..     ...                         ...                             ...
# 669   ZVRA          Zevra Therapeutics                   Biotechnology
# 670   ZVSA        ZyVersa Therapeutics                   Biotechnology
# 671    ZWS  Zurn Elkay Water Solutions  Pollution & Treatment Controls
# 672   ZYME                   Zymeworks                   Biotechnology
# 673   ZYXI                       Zynex            Medical Distribution
#
#     Market Cap
# 0      703.39M
# 1        1.79M
# 2       30.49M
# 3      625.39M
# 4        1.96M
# ..         ...
# ...

# %% [markdown]
# gộp tất cả các bảng dữ liệu lại với nhau

# %%
pd.concat([df1,df2,df3,df4,df5,df6],ignore_index=True).to_csv('symboltock.csv')
